# %%
# !pip install spams
# Out:
# ...
#      |████████████████████████████████| 1.6MB 8.0MB/s
# ...
#   Created wheel for spams: filename=spams-2.6.2.5-cp37-cp37m-linux_x86_64.whl size=4516306 sha256=a28070f428bb37c4f92391a7d05a1d3f0ca26a5865efc1314411a76b23e642f4
#   Stored in directory: /root/.cache/pip/wheels/ba/6f/08/d9d013b9e3ac5ce8f10e67573f38a366c907f99299d5d7711a
# Successfully built spams
# ...

# %%
cd '/content/drive/MyDrive/code_nucleisegnet'
# Out:
# /content/drive/MyDrive/code_nucleisegnet

# %%
# !python color_norm.py
# Out:
# stain normalizing and cropping patches of train images and masks ...
# 100% 24/24 [01:49<00:00,  4.58s/it]
# stain normalizing and cropping patches of validation images and masks ...
# 100% 6/6 [00:25<00:00,  4.17s/it]
# stain normalizing and cropping patches of test images ...
# 100% 14/14 [00:57<00:00,  4.09s/it]
# 100% 14/14 [00:00<00:00, 16.66it/s]
# 100% 6/6 [00:00<00:00, 16.60it/s]
# 100% 24/24 [00:01<00:00, 15.52it/s]

# %%
# !python main.py
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 256, 256, 32) 1344        batch_normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# !python test.py
# Out:
# Predicting the masks ===========>
# 100% 224/224 [00:41<00:00,  5.44it/s]
# Joining the segmented patches to original sized masks ===========>
# Writing segmented masks to image files ===========>
# 100% 14/14 [00:00<00:00, 249.91it/s]
# Segmented images are saved in /content/results
# Scores for the segmented output ===========>
# ID-TCGA-RD-A8N9-01A-01-TS1  IOU: 0.671, DICE: 0.803
# ID-TCGA-RD-A8N9-01A-01-TS1  IOU: 0.589, DICE: 0.742
# ID-TCGA-RD-A8N9-01A-01-TS1  IOU: 0.614, DICE: 0.761
# ID-TCGA-RD-A8N9-01A-01-TS1  IOU: 0.621, DICE: 0.766
# ID-TCGA-RD-A8N9-01A-01-TS1  IOU: 0.687, DICE: 0.814
# ID-TCGA-RD-A8N9-01A-01-TS1  IOU: 0.645, DICE: 0.784
# ID-TCGA-RD-A8N9-01A-01-TS1  IOU: 0.797, DICE: 0.887
# ID-TCGA-RD-A8N9-01A-01-TS1  IOU: 0.749, DICE: 0.857
# ID-TCGA-RD-A8N9-01A-01-TS1  IOU: 0.67, DICE: 0.803
# ID-TCGA-RD-A8N9-01A-01-TS1  IOU: 0.689, DICE: 0.816
# ID-TCGA-RD-A8N9-01A-01-TS1  IOU: 0.647, DICE: 0.785
# ID-TCGA-RD-A8N9-01A-01-TS1  IOU: 0.759, DICE: 0.863
# ...
